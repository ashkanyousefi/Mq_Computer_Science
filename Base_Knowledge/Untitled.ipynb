# %%
conda install pytorch torchvision cudatoolkit=10.1 -c pytorch
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\ashka\Anaconda3
#
#   added / updated specs:
#     - cudatoolkit=10.1
#     - pytorch
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.1.1   |                0         125 KB
#     certifi-2019.11.28         |           py37_0         154 KB
#     conda-4.8.3                |           py37_0         2.8 MB
#     cudatoolkit-10.1.243       |       h74a9793_0       300.3 MB
#     ninja-1.9.0                |   py37h74a9793_0         238 KB
#     openssl-1.1.1e             |       he774522_0         4.8 MB
#     pytorch-1.4.0              |py3.7_cuda101_cudnn7_0       472.8 MB  pytorch
#     torchvision-0.5.0          |       py37_cu101         6.4 MB  pytorch
#     vs2015_runtime-14.16.27012 |       hf0eaf9b_1         1.1 MB
# ...
